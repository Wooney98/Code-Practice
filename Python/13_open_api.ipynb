# %% [markdown]
# <a href="https://colab.research.google.com/github/Wooney98/playdata-python/blob/main/13_open_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Open API 란?
# - API(application programming interface)는 프로그램의 특정한 부분에 요청해서 그 안에 있는 데이터와 서비스(기능)를 이용할 수 있게 해주는 소프트웨어 인터페이스
# - 다양한 데이터를 어디서나 쉽게 이용할 수 있도록 개방된 API

# %% [markdown]
# ![20220713155346.png](data:image/png;base64,...)

# %% [markdown]
# # 주요 Open API 제공처
# - 공공데이터포털 (http://www.data.go.kr/)
# - 네이버 Developers 센터 (http://developers.naver.com/)
# - 구글 디벨로퍼 (http://developers.google.com/)
# - 페이스북 for 디벨로퍼 (http://developers.facebook.com/)
# - 카카오톡 디펠로터 ((http://developers.kakao.com/)

# %% [markdown]
# # HTTP(Hyper Text Transfer Protocol) 란?
# - HTML, Plain text, JSON, XML , 이미지 , 동영상 등 다양한 형태의 정보도 전송하는 프로토콜
# - HTTP의 동작 방식

# %% [markdown]
# ## HTTP 통신 방식

# %% [markdown]
# ![20220713160019.png](data:image/png;base64,...)

# %% [markdown]
# ## HTTP Packet
# - HTTP 통신으로 서버와 클라이언트 사이에 주고 받는 데이터를 말한다.
# - Request Header
#     - 클라이언트가 서버에 요청할 때 존재하는 헤더로 요청한 URL, Method, 브라우저 정보 등이 포함되어 있다.
# - Respone Header
#     - 서버가 클라이언트의 요청에 대한 응답을 할 때 존재하는 헤더로 콘텐츠에 사용된 인코딩, 응답을 생성하기 위해 서버 시스템에서 사용되는 서버 소프트웨어 및 기타 정보 등이 포함되어 있다.
# - HTTP Body
#     - 서버에서 응답시 클라이언트가 요청한 실제 데이터가 포함되어 있다.
#     - HTML , image, css , javascript, text ...

# %% [markdown]
# ![images_duckchanahn_post_f2e9676a-feb1-45bb-99ad-00e1f054cf19_http-header-and-body.png](data:image/png;base64,...)

# %% [markdown]
# ## HTTP 메소드 와 상태코드
# - HTTP 메소드란?
#     - 서버에 요청을 보내는 방식
#     - GET 방식 : URL 에 데이터를 담아 요청
#     - POST 방식 : GET 방식과는 달리 body영역에 데이터를 담아 요청
# - HTTP 상태 코드(응답)
#     - 클라이언트가 서버에 요청을 하면, 서버는 요청에 대한 처리 상태를 숫자로 반환하는데 이를 상태 코드라고 한다.
#     - 2xx: 요청성공(ex. 200)
#     - 3xx: 요청이 유효하지만 주소가 변경(ex. 301)
#         - 자동으로 변경된 주소로 이동
#     - 4xx: 클라이언트 오류(ex. 404)
#     - 5xx: 서버 오류(ex. 500)
#     - https://developer.mozilla.org/ko/docs/Web/HTTP/Status

# %% [markdown]
# ## URL 구조

# %% [markdown]
# ![20220713160500.png](data:image/png;base64,...)

# %% [markdown]
# # requests 라이브러리
# - http 요청을 보내 응답을 받을 수 있다.

# %%
import requests

# %%
res = requests.get("https://naver.com") # 응답 객체가 반환된다.
res
# Out:
# <Response [200]>

# %%
res.status_code # 내 요청이 성공, 404 = Error!
# Out:
# 200

# %%
res.encoding # 응답 컨텐츠에 대한 인코딩 정보
# Out:
# 'UTF-8'

# %%
res.text
# Out:
# '\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네
# ...

# %%
res.request.method # 요청방식도 확인할 수 있다.
# Out:
# 'GET'

# %%
res.request.headers # 요청에 대한 헤더정보
# Out:
# {'User-Agent': 'python-requests/2.23.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
res.headers # 응답에 대한 헤더정보
# Out:
# {'Server': 'NWS', 'Content-Type': 'text/html; charset=UTF-8', 'Cache-Control': 'no-cache, no-store, must-revalidate', 'Pragma': 'no-cache', 'P3P': 'CP="CAO DSP CURa ADMa TAIa PSAa OUR LAW STP PHY ONL UNI PUR FIN COM NAV INT DEM STA PRE"', 'X-Frame-Options': 'DENY', 'X-XSS-Protection': '1; mode=block', 'Strict-Transport-Security': 'max-age=63072000; includeSubdomains', 'Referrer-Policy': 'unsafe-url', 'Content-Encoding': 'gzip', 'Content-Length': '37265', 'Date': 'Thu, 18 Aug 2022 00:48:36 GMT', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding'}

# %% [markdown]
# # 오픈 api 사용해보기
# - 요청주소 : http://apis.data.go.kr/B553734/iseelectricprod/getElectricProduction
# - 요청 변수
#     - 인증키	ServiceKey	100	인증키	공공데이터포털에서 받은 인증키
#     - 리턴타입	returnType	4	xml/json	결과처리 xml/json
#     - 한 페이지 결과 수	numOfRows	4	10	한 페이지 결과 수
#     - 페이지 번호	pageNo	4	1	페이지번호
#     - 검색시작년월	startDate	7	2016-01	검색 시작 년월
#     - 검색종료년월	endDate	7 2019-12	검색 종료 년월

# %% [markdown]
# # URL 인코딩
# - 퍼센트(%) 인코딩이라고도 함
# - 영문자와 숫자, 일부 특수문자를 제외한 URL에서 사용할 수 없는 한글이나 특수문자들을 인코딩한다.

# %% [markdown]
# - 디코딩 되어있는 서비스키를 사용할 경우

# %%
ServiceKey = "디코딩된 서비스키"

# %%
returnType = "xml"
startDate = "2022-01"
endDate = "2022-03"

url = "http://apis.data.go.kr/B553734/iseelectricprod/getElectricProduction"
query = f"?ServiceKey={ServiceKey}&returnType={returnType}&startDate={startDate}&endDate={endDate}"
url+query
# Out:
# 'http://apis.data.go.kr/B553734/iseelectricprod/getElectricProduction?ServiceKey=디코딩 서비스키 넣으면됨.&returnType=xml&startDate=2022-01&endDate=2022-03'

# %%
res = requests.get(url+query)
res.status_code
# Out:
# 200

# %% [markdown]
# - 인코딩하기

# %%
ServiceKey = "디코딩 서비스키"
ServiceKey = requests.utils.quote(ServiceKey) # 인코딩하는 메소드
ServiceKey
# Out:
# '%EB%94%94%EC%BD%94%EB%94%A9%20%EC%84%9C%EB%B9%84%EC%8A%A4%ED%82%A4'

# %%
returnType = "xml"
startDate = "2022-01"
endDate = "2022-03"

url = "http://apis.data.go.kr/B553734/iseelectricprod/getElectricProduction"
query = f"?ServiceKey={ServiceKey}&returnType={returnType}&startDate={startDate}&endDate={endDate}"

res = requests.get(url+query)
res.status_code
# Out:
# 200

# %%
res.text
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\n<response><header><resultCode>00</resultCode><description>서울에너지공사 발전소 월별 전기생산량(발전량)</description><resultMsg>NORMAL CODE</resultMsg></header><body><pageNo>1</pageNo><totalCount>6</totalCount><items><item><unit>kWh</unit><elecprodqty>9217900.00</elecprodqty><dates>2022-03</dates><branchNm>동부지사</branchNm><branchCd>2</branchCd></item><item><unit>kWh</unit><elecprodqty>5849090.50</elecprodqty><dates>2022-03</dates><branchNm>서부지사</branchNm><branchCd>1</branchCd></item><item><unit>kWh</unit><elecprodqty>9113300.00</elecprodqty><dates>2022-02</dates><branchNm>동부지사</branchNm><branchCd>2</branchCd></item><item><unit>kWh</unit><elecprodqty>8757266.00</elecprodqty><dates>2022-02</dates><branchNm>서부지사</branchNm><branchCd>1</branchCd></item><item><unit>kWh</unit><elecprodqty>12911900.00</elecprodqty><dates>2022-01</dates><branchNm>동부지사</branchNm><branchCd>2</branchCd></item><item><unit>kWh</unit><elecprodqty>8964872.00</elecprodqty><dates>2022-01</dates><br
# ...

# %% [markdown]
# - xml데이터를 딕셔너리 형태로 변환해보기

# %%
# !pip install xmltodict
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import xmltodict

# %%
dict_data = xmltodict.parse(res.text)
dict_data
# Out:
# {'response': {'header': {'resultCode': '00',
#    'description': '서울에너지공사 발전소 월별 전기생산량(발전량)',
#    'resultMsg': 'NORMAL CODE'},
#   'body': {'pageNo': '1',
#    'totalCount': '6',
#    'items': {'item': [{'unit': 'kWh',
#       'elecprodqty': '9217900.00',
#       'dates': '2022-03',
#       'branchNm': '동부지사',
#       'branchCd': '2'},
#      {'unit': 'kWh',
#       'elecprodqty': '5849090.50',
#       'dates': '2022-03',
#       'branchNm': '서부지사',
#       'branchCd': '1'},
#      {'unit': 'kWh',
#       'elecprodqty': '9113300.00',
#       'dates': '2022-02',
#       'branchNm': '동부지사',
#       'branchCd': '2'},
#      {'unit': 'kWh',
#       'elecprodqty': '8757266.00',
#       'dates': '2022-02',
#       'branchNm': '서부지사',
#       'branchCd': '1'},
#      {'unit': 'kWh',
#       'elecprodqty': '12911900.00',
#       'dates': '2022-01',
#       'branchNm': '동부지사',
#       'branchCd': '2'},
#      {'unit': 'kWh',
#       'elecprodqty': '8964872.00',
#       'dates': '2022-01',
# ...

# %%
import pprint as pp
pp.pprint(dict_data)
# Out:
# {'response': {'body': {'items': {'item': [{'branchCd': '2',
#                                            'branchNm': '동부지사',
#                                            'dates': '2022-03',
#                                            'elecprodqty': '9217900.00',
#                                            'unit': 'kWh'},
#                                           {'branchCd': '1',
#                                            'branchNm': '서부지사',
#                                            'dates': '2022-03',
#                                            'elecprodqty': '5849090.50',
#                                            'unit': 'kWh'},
#                                           {'branchCd': '2',
#                                            'branchNm': '동부지사',
#                                            'dates': '2022-02',
#                                            'elecprodqty': '9113300.00',
#                                            'unit': 'kWh'},
# ...

# %%
dict_data["response"]["body"]["items"]["item"]
# Out:
# [{'unit': 'kWh',
#   'elecprodqty': '9217900.00',
#   'dates': '2022-03',
#   'branchNm': '동부지사',
#   'branchCd': '2'},
#  {'unit': 'kWh',
#   'elecprodqty': '5849090.50',
#   'dates': '2022-03',
#   'branchNm': '서부지사',
#   'branchCd': '1'},
#  {'unit': 'kWh',
#   'elecprodqty': '9113300.00',
#   'dates': '2022-02',
#   'branchNm': '동부지사',
#   'branchCd': '2'},
#  {'unit': 'kWh',
#   'elecprodqty': '8757266.00',
#   'dates': '2022-02',
#   'branchNm': '서부지사',
#   'branchCd': '1'},
#  {'unit': 'kWh',
#   'elecprodqty': '12911900.00',
#   'dates': '2022-01',
#   'branchNm': '동부지사',
#   'branchCd': '2'},
#  {'unit': 'kWh',
#   'elecprodqty': '8964872.00',
#   'dates': '2022-01',
#   'branchNm': '서부지사',
#   'branchCd': '1'}]

# %% [markdown]
# - json 형태로 변환하기

# %%
returnType = "json" # >> json으로 리턴
startDate = "2022-01"
endDate = "2022-03"

url = "http://apis.data.go.kr/B553734/iseelectricprod/getElectricProduction"
query = f"?ServiceKey={ServiceKey}&returnType={returnType}&startDate={startDate}&endDate={endDate}"

res = requests.get(url+query)
res.status_code
# Out:
# 200

# %%
data = res.json() # json 파일을 딕셔너리형태로 변환해서 반환

# %%
pp.pprint(data)
# Out:
# {'body': {'items': {'item': [{'branchCd': '2',
#                               'branchNm': '동부지사',
#                               'dates': '2022-03',
#                               'elecprodqty': '9217900.00',
#                               'unit': 'kWh'},
#                              {'branchCd': '1',
#                               'branchNm': '서부지사',
#                               'dates': '2022-03',
#                               'elecprodqty': '5849090.50',
#                               'unit': 'kWh'},
#                              {'branchCd': '2',
#                               'branchNm': '동부지사',
#                               'dates': '2022-02',
#                               'elecprodqty': '9113300.00',
#                               'unit': 'kWh'},
#                              {'branchCd': '1',
#                               'branchNm': '서부지사',
#                               'dates': '2022-02',
#                               'elecprodqty': '8757266.00',
# ...

# %% [markdown]
# # 네이버 Open API 사용해보기

# %% [markdown]
# ## 검색 API

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = ""
client_secret = ""
encText = urllib.parse.quote("빅데이터와 인공지능")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Thu, 18 Aug 2022 11:37:47 +0900",
# 	"total":253558,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>인공지능<\/b>, <b>빅데이터<\/b>특허 발명 보호를 위한 등록 방법",
# 			"link":"https:\/\/blog.naver.com\/jninsa?Redirect=Log&logNo=222849778387",
# 			"description":"저 역시 BM\/<b>인공지능<\/b>\/<b>빅데이터<\/b>\/플랫폼분야 등에서 전문변리사로 활동 중인 만큼, 문의해 주시는 내용을 직접 검토하여 피드백 드리고 있습니다. 출원 전 주의해야 할 부분이 있다면 실무적으로 봤을 때, 일반인이... ",
# 			"bloggername":"윤 변리사의 실무 이야기",
# 			"bloggerlink":"https:\/\/blog.naver.com\/jninsa",
# 			"postdate":"20220816"
# 		},
# 		{
# 			"title":"<b>빅데이터와 인공지능<\/b> : 세상을 바꾸는 기술 이야기",
# 			"link":"https:\/\/blog.naver.com\/pareko?Redirect=Log&logNo=222609514030",
# 			"description":"책 소개 이 책은 <b>빅데이터와 인공지능<\/b>을 주제로 생활변화에 대한 인문학 이야기 입니다. &quot;호랑이는... 05 인공지능과의 동거 06 삐딱하게 바라본 기술의 진보 07 현실과 4차 산업의 괴리 08 진정한 4차... ",
# 			"bloggername":"순돌아범",
# 			"bloggerlink":"https:\/\/blog.naver.com\/pareko",
# 			"postdate":"20211231"
# 		},
# 		{
# ...

# %% [markdown]
# - 네이버 검색 API를 이용하여 영화정보 받아오기

# %%
import requests

client_id = ""
client_secret = ""

# %%
headers = {
    "X-Naver-Client-Id": client_id,
    "X-Naver-Client-Secret": client_secret
}
url = "https://openapi.naver.com/v1/search/movie.json" # 요청 URL만(쿼리부분 제외)
params = {
    "query":"범죄도시"
}

# %%
res = requests.get(url,params=params,headers=headers)
if res.status_code == 200:
    data = res.json()
else:
    print(f"Error Code:{res.status_code}")

# %%
pp.pprint(data)
# Out:
# {'display': 8,
#  'items': [{'actor': '마동석|손석구|최귀화|',
#             'director': '이상용|',
#             'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1926/192608_P62_104337.jpg',
#             'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=192608',
#             'pubDate': '2022',
#             'subtitle': 'the roundup',
#             'title': '<b>범죄도시</b>2',
#             'userRating': '9.34'},
#            {'actor': '마동석|이준혁|아오키 무네타카|이범수|김민재|전석호|고규필|',
#             'director': '이상용|',
#             'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/2188/218815_P07_143955.jpg',
#             'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=218815',
#             'pubDate': '2022',
#             'subtitle': 'The Roundup : No Way Out',
#             'title': '<b>범죄도시</b>3',
#             'userRating': '0.00'},
#            {'actor': '베리 코빈|클린트 제임스|',
#             'director': '로버트 콘웨이|',
# ...

# %%
data["items"]
# Out:
# [{'title': '<b>범죄도시</b>2',
#   'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=192608',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1926/192608_P62_104337.jpg',
#   'subtitle': 'the roundup',
#   'pubDate': '2022',
#   'director': '이상용|',
#   'actor': '마동석|손석구|최귀화|',
#   'userRating': '9.34'},
#  {'title': '<b>범죄도시</b>3',
#   'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=218815',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/2188/218815_P07_143955.jpg',
#   'subtitle': 'The Roundup : No Way Out',
#   'pubDate': '2022',
#   'director': '이상용|',
#   'actor': '마동석|이준혁|아오키 무네타카|이범수|김민재|전석호|고규필|',
#   'userRating': '0.00'},
#  {'title': '<b>범죄도시</b>: 나쁜놈들 전성시대',
#   'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=200744',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/2007/200744_P01_134853.jpg',
#   'subtitle': 'Eminence Hill',
#   'pubDate': '2019',
#   'director': '로버트 콘웨이|',
#   'actor': '베리 코빈|클린트 제임스|',
# ...

# %% [markdown]
# - 데이터 프레임으로 변환해보기

# %%
import pandas as pd
pd.DataFrame(data["items"])
# Out:
#                     title                                               link  \
# 0            <b>범죄도시</b>2  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 1            <b>범죄도시</b>3  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 2  <b>범죄도시</b>: 나쁜놈들 전성시대  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 3     대<b>범죄도시</b>: 나쁜녀석들  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 4             <b>범죄도시</b>  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 5        바이스: <b>범죄도시</b>  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 6          줄루 <b>범죄도시</b>  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 7             <b>범죄도시</b>  https://movie.naver.com/movie/bi/mi/basic.nhn?...
#
#                                                image  \
# 0  https://ssl.pstatic.net/imgmovie/mdi/mit110/19...
# 1  https://ssl.pstatic.net/imgmovie/mdi/mit110/21...
# 2  https://ssl.pstatic.net/imgmovie/mdi/mit110/20...
# 3  https://ssl.pstatic.net/imgmovie/mdi/mit110/17...
# ...

# %% [markdown]
# ```
# 네이버 검색 api 함수 만들어 보기
# 요청 url 과 Client Id , Client-Secret , 그리고 요청 변수들을 인자로 받는 함수를 만드시오.
# api 요청후에 결과값들을 반환하는 함수를 작성하시오.
# 상태코드가 200 아닐경우 응답객체를 프린트함수로 출력하고 None 객체를반환하시오.
# ex)
# params = {
#     "query" : "파이토치",
#     "display" : 1
# }
# url = "https://openapi.naver.com/v1/search/book.json"
# search_api(url ,client_id,client_secret,params)
# Output:
# {'display': 1,
#  'items': [{'author': '엘리 스티븐스^루카 안티가^토마스 피이만',
#    'description': '파이토치 핵심 개발진이 직접 집필한 책으로, 최고 실무자가 바로 옆에 앉아서 딥러닝의 기초부터
#    실제 프로젝트 활용까지, 모델 성능 평가와 개선 방안을 차근차근 알려주는 느낌을 준다! \n텐서, 신경망 같은 딥러닝 데이터 구조의
#     개념과 원리부터 파이토치와 의료 데이터를 활용한 완전하게 동작 가능한 딥러닝 서비스 구축부터 배포까지, 딥러닝 전체 워크플로를
#     모두 다룬다!\n\n이 책에서는 파이토치를 활용해 신경망과 딥러닝 시스템을 만드는 방법을 알려준다.
#     종양 이미지 분류기라는 실전 예제 구축 작업을 바닥부터 배우는 실용적인 내용이 가득하다.
#     동시에 파이토치 텐서 API, 파이썬의 데이터 로딩, 훈련 모니터링, 결과 시각화 등 딥러닝 파이프라인 전체에 대한
#     최고의 실습 사례를 다룬다.
#     \n\n｜ 이 책에서 다루는 내용 ｜\n- 심층 신경망 훈련\n- 모듈과 손실 함수 구현\n- 파이토치 허브의 사전 훈련된 모델 활용
#     \n- 주피터 노트북 코드 샘플 탐구\n- 딥러닝 모델 성능의 분석, 평가, 개선
#     \n- 폐 종양 CT 영상 데이터를 활용한 모델 분석부터 서빙까지 엔드투엔드 모의 암 진단 프로젝트',
#    'discount': '31500',
#    'image': 'https://shopping-phinf.pstatic.net/main_3308537/33085370622.20220702094910.jpg',
#    'isbn': '9791189909413',
#    'link': 'https://search.shopping.naver.com/book/catalog/33085370622',
#    'pubdate': '20220622',
#    'publisher': '책만',
#    'title': '파이토치 딥러닝 마스터 (모의 암 진단 프로젝트로 배우는 신경망 모델 구축부터 훈련)'}],
#  'lastBuildDate': 'Sun, 31 Jul 2022 18:52:23 +0900',
#  'start': 1,
#  'total': 21}
# ```

# %%
def api_Func(url,client_id,client_secret,search,num):
    headers = {
        "X-Naver-Client-Id": client_id,
        "X-Naver-Client-Secret": client_secret
    }
    params = {
        "query":search,
        "display":num
    }
    res = requests.get(url,params=params,headers=headers)
    if res.status_code == 200:
        data = res.json()
        pp.pprint(data)
    else:
        print(f"Error Code:{res.status_code}")
    
    return data

# %%
Uri = "https://openapi.naver.com/v1/search/book.json"
ID = ""
SECRET = ""

api_Func(Uri,ID,SECRET,"파이토치",1)
# Out:
# {'display': 1,
#  'items': [{'author': '엘리 스티븐스^루카 안티가^토마스 피이만',
#             'description': '파이토치 핵심 개발진이 직접 집필한 책으로, 최고 실무자가 바로 옆에 앉아서 딥러닝의 '
#                            '기초부터 실제 프로젝트 활용까지, 모델 성능 평가와 개선 방안을 차근차근 알려주는 느낌을 '
#                            '준다! \n'
#                            '텐서, 신경망 같은 딥러닝 데이터 구조의 개념과 원리부터 파이토치와 의료 데이터를 활용한 '
#                            '완전하게 동작 가능한 딥러닝 서비스 구축부터 배포까지, 딥러닝 전체 워크플로를 모두 '
#                            '다룬다!\n'
#                            '\n'
#                            '이 책에서는 파이토치를 활용해 신경망과 딥러닝 시스템을 만드는 방법을 알려준다. 종양 '
#                            '이미지 분류기라는 실전 예제 구축 작업을 바닥부터 배우는 실용적인 내용이 가득하다. 동시에 '
#                            '파이토치 텐서 API, 파이썬의 데이터 로딩, 훈련 모니터링, 결과 시각화 등 딥러닝 '
#                            '파이프라인 전체에 대한 최고의 실습 사례를 다룬다. \n'
#                            '\n'
#                            '｜ 이 책에서 다루는 내용 ｜\n'
#                            '- 심층 신경망 훈련\n'
#                            '- 모듈과 손실 함수 구현\n'
# ...

# %% [markdown]
# # 파파고 번역 해보기
# - 요청주소
#     - https://openapi.naver.com/v1/papago/n2mt
# - 원본언어
#     - source
# - 목적언어
#     - target
# - 번역할 텍스트
#     - text

# %%
url = "https://openapi.naver.com/v1/papago/n2mt"

headers = {
    "X-Naver-Client-Id":client_id,
    "X-Naver-Client-Secret":client_secret
}

data = {
    "source": "ko", # 한국어
    "target": "en", # 영어
    "text": "파이썬은 재미있다." 
}

res = requests.post(url,headers=headers,data=data)
result = res.json()
pp.pprint(result)
# Out:
# {'message': {'@service': 'naverservice.nmt.proxy',
#              '@type': 'response',
#              '@version': '1.0.0',
#              'result': {'dict': None,
#                         'engineType': 'N2MT',
#                         'pivot': None,
#                         'srcLangType': 'ko',
#                         'tarDict': None,
#                         'tarLangType': 'en',
#                         'translatedText': 'Python is fun.'}}}

# %%
result["message"]["result"]["translatedText"]
# Out:
# 'Python is fun.'

# %% [markdown]
# - 함수로 만들어보기!

# %%
def translate_api(text,client_id,client_secret,source="ko",target="en"):
    uri = "https://openapi.naver.com/v1/papago/n2mt"
    
    headers = {
    "X-Naver-Client-Id":client_id,
    "X-Naver-Client-Secret":client_secret
    }

    data = {
        "source": source, # 한국어
        "target": target, # 영어
        "text": text 
    }

    res = requests.post(url,headers=headers,data=data)
    result = res.json()

    if res.status_code == 200:
        result = result["message"]["result"]["translatedText"]
    else:
        print(f"Error Code:{res.status_code}")

    return result

# %%
ID = ""
SECRET = ""

translate_api("파이썬은 재밌다.",ID,SECRET)
# Out:
# 'Python is fun.'

# %% [markdown]
# # yaml 파일 불러오기

# %%
# !pip install git+https://github.com/Wooney98/API_Project.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/Wooney98/API_Project.git to /tmp/pip-req-build-w6ptrkbk
#   Running command git clone -q https://github.com/Wooney98/API_Project.git /tmp/pip-req-build-w6ptrkbk
# ...
#   Created wheel for myapi: filename=myapi-0.0.1-py3-none-any.whl size=1758 sha256=c1bd527e2077561dc3c2624aeef602e248bd48763e0b976ad5a2c55732bceb39
#   Stored in directory: /tmp/pip-ephem-wheel-cache-g9xrd76v/wheels/d3/ee/f3/5fbd63cf7d19e1784700f7c79ab1a3e82cc585b9f520aee738
# Successfully built myapi
# ...

# %%
from my_api import naver_api

# %% [markdown]
# - 구글 드라이브에서 yaml 불러오기
# - 인증키를 오픈소스로 공개하면 보안상 문제가 많으므로 yaml파일의 경로를 통해 인증키 받기

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import yaml
KEY_FILE = "/content/drive/MyDrive/Colab Notebooks/Data/local.yml"
with open(KEY_FILE,'r') as f:
    naver_keys = yaml.load(f)
CLIENT_ID = naver_keys["CLIENT_ID"]
CLIENT_SECRET = naver_keys["CLIENT_SECRET"]

# %%
url = "https://openapi.naver.com/v1/search/kin.json"
params ={
    "query":"부트캠프 후기",
    "display" : 5
}
naver_api.search_api(url,CLIENT_ID,CLIENT_SECRET,params)
# Out:
# {'lastBuildDate': 'Fri, 19 Aug 2022 15:36:18 +0900',
#  'total': 536,
#  'start': 1,
#  'display': 5,
#  'items': [{'title': '코딩 <b>부트캠프</b> 취업까지 연결?',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=406&docId=420611294&qb=67aA7Yq47Lqg7ZSEIO2bhOq4sA==&enc=utf8&section=kin.qna&rank=1&search_sort=0&spq=0',
#    'description': '... 제로베이스라는 코딩 <b>부트캠프</b>에 각종 프로그램도 있고 합격자 <b>후기</b>를 보니 대기업으로 취업까지 성공한 케이스가 많이 있어서 궁금 합니다. 제로베이스 코딩 <b>부트캠프</b>에서는 교육생 대상으로 취업까지 파트너사로 연계가... '},
#   {'title': '코딩 <b>부트캠프</b> 추천',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8070402&docId=415825241&qb=67aA7Yq47Lqg7ZSEIO2bhOq4sA==&enc=utf8&section=kin.qna&rank=2&search_sort=0&spq=0',
#    'description': '코딩<b>부트캠프</b> 추천좀 해주세요 찾아본곳중엔 항해99가 괜찮은거같은데 혹시 <b>후기</b>좀 알수 있을까요?  코딩 <b>부트캠프</b> 추천 코딩<b>부트캠프</b> 추천좀 해주세요 찾아본곳중엔 항해99가 괜찮은거같은데 혹시 <b>후기</b>좀 알수 있을까요?... '},
#   {'title': 'IT<b>부트캠프</b> KG아이티뱅크 괜찮은가요?',
# ...

# %%
text = "내일은 주말, 푹 쉬자!"
url = "https://openapi.naver.com/v1/papago/n2mt"
naver_api.translate_api(text,url,CLIENT_ID,CLIENT_SECRET)
# Out:
# "Tomorrow is the weekend, let's rest well!"
